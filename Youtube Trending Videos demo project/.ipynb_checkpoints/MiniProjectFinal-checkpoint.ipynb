# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy as sp
import glob
import json
from datetime import datetime
import re

# %% [markdown]
# # Reading and cleaning the data

# %% [markdown]
# ## Reading the data for Germany, Canada, French, United States, and Great Britain

# %%
files = [i for i in glob.glob('.\\utubedata\\*.{}'.format('csv'))]

dfs = list()

for csv in files:
    df = pd.read_csv(csv, index_col='video_id')
    df['country'] = csv[12:14]
    dfs.append(df)

my_df = pd.concat(dfs)
my_df.head(3)
# Out:
#             trending_date                                              title  \
# video_id
# n1WpP7iowLc      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 0dBIkQ4Mz1M      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
#
#             channel_title  category_id              publish_time  \
# video_id
# n1WpP7iowLc    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 0dBIkQ4Mz1M     iDubbbzTV           23  2017-11-13T17:00:00.000Z
# 5qpjK5DgCt4  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
#
#                                                           tags     views  \
# video_id
# n1WpP7iowLc  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579
# 0dBIkQ4Mz1M  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651
# 5qpjK5DgCt4  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434
#
#               likes  dislikes  comment_count  \
# video_id
# n1WpP7iowLc  787425     43420         125882
# 0dBIkQ4Mz1M  127794      1688          13030
# 5qpjK5DgCt4  146035      5339           8181
#
#                                              thumbnail_link  \
# video_id
# n1WpP7iowLc  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 0dBIkQ4Mz1M  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 5qpjK5DgCt4  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
#
#              comments_disabled  ratings_disabled  video_error_or_removed  \
# video_id
# n1WpP7iowLc              False             False                   False
# 0dBIkQ4Mz1M              False             False                   False
# 5qpjK5DgCt4              False             False                   False
#
#                                                    description country
# video_id
# n1WpP7iowLc  Eminem's new track Walk on Water ft. Beyoncé i...      CA
# 0dBIkQ4Mz1M  STill got a lot of packages. Probably will las...      CA
# 5qpjK5DgCt4  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...      CA

# %%
my_df.shape
# Out:
# (202310, 16)

# %% [markdown]
# ## Cleaning, reformatting date, time, and inserting categories

# %%
mod_df = my_df.copy()
mod_df['trending_date'] = pd.to_datetime(mod_df['trending_date'], errors = 'coerce', format = '%y.%d.%m')
mod_df['publish_time'] = pd.to_datetime(mod_df['publish_time'], errors = 'coerce', format = '%Y-%m-%dT%H:%M:%S.%fZ')
                                             
mod_df = mod_df[mod_df['trending_date'].notnull()]                                           
mod_df = mod_df[mod_df['publish_time'].notnull()]
                                             
mod_df = mod_df.dropna(how = 'any', inplace=  False, axis = 0)

mod_df.insert(4, 'publish_date', mod_df['publish_time'].dt.date)
mod_df['publish_time'] = mod_df['publish_time'].dt.time

mod_df = mod_df.reset_index().drop_duplicates('video_id', keep = 'last').set_index('video_id')

print(mod_df.shape)
mod_df.head()
# Out:
# (74959, 17)
# (195368, 17)
#             trending_date                                              title  \
# video_id
# FyZMnhUtLfE    2017-11-14         猎场 | Game Of Hunting 12【TV版】（胡歌、張嘉譯、祖峰等主演）
# 7MxiQ4v0EnE    2017-11-14  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...
# gifPYwArCVQ    2017-11-14                     Fake Pet Smart Employee Prank!
# fy-CuCzaPp8    2017-11-14  Rooster Teeth Animated Adventures - Drunk Baby...
# aVTAU_4i9AY    2017-11-14                        Throwing Things Into A Fan!
#
#              channel_title  category_id publish_date publish_time  \
# video_id
# FyZMnhUtLfE           大劇獨播            1   2017-11-12     16:00:01
# 7MxiQ4v0EnE  Speed Records           10   2017-11-11     16:41:15
# gifPYwArCVQ           NELK           23   2017-11-13     01:30:01
# fy-CuCzaPp8  Rooster Teeth            1   2017-11-13     14:00:03
# aVTAU_4i9AY           REKT           24   2017-11-12     23:00:00
#
#                                                           tags    views  \
# video_id
# FyZMnhUtLfE  電視劇|"大陸電視劇"|"猎场"|"职场"|"商战"|"爱情"|"都市"|"胡歌"|"陈龙"...   158815
# 7MxiQ4v0EnE  punjabi songs|"punjabi bhangra"|"punjabi music...  5718766
# gifPYwArCVQ      prank|"pranks"|"nelk"|"nelkfilmz"|"nelkfilms"   557883
# fy-CuCzaPp8  Rooster Teeth|"RT"|"animation"|"television"|"f...   308568
# aVTAU_4i9AY  Industrial Fan|"Industrial Fan Destruction"|"T...   370827
#
#               likes  dislikes  comment_count  \
# video_id
# FyZMnhUtLfE     218        30            186
# 7MxiQ4v0EnE  127477      7134           8063
# gifPYwArCVQ   44558       621           9619
# fy-CuCzaPp8   19541        70            495
# aVTAU_4i9AY   12150       325           2352
#
#                                              thumbnail_link  \
# video_id
# FyZMnhUtLfE  https://i.ytimg.com/vi/FyZMnhUtLfE/default.jpg
# 7MxiQ4v0EnE  https://i.ytimg.com/vi/7MxiQ4v0EnE/default.jpg
# gifPYwArCVQ  https://i.ytimg.com/vi/gifPYwArCVQ/default.jpg
# fy-CuCzaPp8  https://i.ytimg.com/vi/fy-CuCzaPp8/default.jpg
# aVTAU_4i9AY  https://i.ytimg.com/vi/aVTAU_4i9AY/default.jpg
#
#              comments_disabled  ratings_disabled  video_error_or_removed  \
# video_id
# FyZMnhUtLfE              False             False                   False
# 7MxiQ4v0EnE              False             False                   False
# gifPYwArCVQ              False             False                   False
# fy-CuCzaPp8              False             False                   False
# aVTAU_4i9AY              False             False                   False
#
#                                                    description country
# video_id
# FyZMnhUtLfE  Thanks for watching the drama! Help more peopl...      CA
# 7MxiQ4v0EnE  Song - Daang\nSinger - Mankirt Aulakh\nFaceboo...      CA
# gifPYwArCVQ  3 Days left to cop NELK merch: https://nelk.ca...      CA
# fy-CuCzaPp8  Miles gets stuck at work one night watching ov...      CA
# aVTAU_4i9AY  Destroying Unbreakable Glasses! ➡ https://www....      CA

# %%
mod_df['category_id'] = mod_df['category_id'].astype(str)
mod_df_full['category_id'] = mod_df_full['category_id'].astype(str)

category_id = {}

with open('./utubedata/US_category_id.json', 'r') as f:
    data = json.load(f)
    for category in data['items']:
        category_id[category['id']] = category['snippet']['title']

mod_df.insert(4, 'category', mod_df['category_id'].map(category_id))

# %%
category_list = mod_df['category'].unique()
category_list
# Out:
# array(['Film & Animation', 'Music', 'Comedy', 'Entertainment',
#        'People & Blogs', 'Gaming', 'Sports', 'News & Politics',
#        'Travel & Events', 'Autos & Vehicles', 'Howto & Style',
#        'Pets & Animals', 'Education', 'Science & Technology', 'Shows',
#        'Nonprofits & Activism', 'Trailers', 'Movies'], dtype=object)

# %% [markdown]
# Let's see how many videos do we have for each category

# %%
for categ in category_list :
    print(categ , mod_df[mod_df['category'] == categ].shape)
# Out:
# Film & Animation (3630, 18)
# Music (4923, 18)
# Comedy (5274, 18)
# Entertainment (23303, 18)
# People & Blogs (9597, 18)
# Gaming (2782, 18)
# Sports (6599, 18)
# News & Politics (7616, 18)
# Travel & Events (394, 18)
# Autos & Vehicles (1461, 18)
# Howto & Style (4635, 18)
# Pets & Animals (632, 18)
# Education (1811, 18)
# Science & Technology (1790, 18)
# Shows (166, 18)
# Nonprofits & Activism (334, 18)
# Trailers (2, 18)
# Movies (10, 18)

# %% [markdown]
# 'Trailers' and 'Movies' categories have way few videos, which could lead to misguiding analysis. So let's drop them -- we are dropping only 12 videos (our whole dataset now has 74900+ inputs)

# %%
mod_df = mod_df.drop(index = mod_df[mod_df['category'] == 'Movies'].index.tolist())
mod_df = mod_df.drop(index = mod_df[mod_df['category'] == 'Trailers'].index.tolist())

# %%
category_list = mod_df['category'].unique()
category_list
# Out:
# array(['Film & Animation', 'Music', 'Comedy', 'Entertainment',
#        'People & Blogs', 'Gaming', 'Sports', 'News & Politics',
#        'Travel & Events', 'Autos & Vehicles', 'Howto & Style',
#        'Pets & Animals', 'Education', 'Science & Technology', 'Shows',
#        'Nonprofits & Activism'], dtype=object)

# %%
for categ in category_list :
    print(categ , mod_df[mod_df['category'] == categ].shape)
# Out:
# Film & Animation (3630, 18)
# Music (4923, 18)
# Comedy (5274, 18)
# Entertainment (23303, 18)
# People & Blogs (9597, 18)
# Gaming (2782, 18)
# Sports (6599, 18)
# News & Politics (7616, 18)
# Travel & Events (394, 18)
# Autos & Vehicles (1461, 18)
# Howto & Style (4635, 18)
# Pets & Animals (632, 18)
# Education (1811, 18)
# Science & Technology (1790, 18)
# Shows (166, 18)
# Nonprofits & Activism (334, 18)

# %% [markdown]
# # Numerical Analysis

# %% [markdown]
# ## Univariate analysis

# %% [markdown]
# ### Analysis on 'views', 'likes', 'dislikes', and 'comment_count'

# %%
mod_df.describe()
# Out:
#               views         likes      dislikes  comment_count
# count  7.494700e+04  7.494700e+04  7.494700e+04   7.494700e+04
# mean   5.185779e+05  1.426788e+04  7.704594e+02   1.740344e+03
# std    3.921224e+06  7.330830e+04  8.230495e+03   1.023608e+04
# min    2.840000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    2.267500e+04  4.260000e+02  2.200000e+01   6.900000e+01
# 50%    9.891600e+04  2.143000e+03  9.400000e+01   3.150000e+02
# 75%    3.395570e+05  8.386500e+03  3.430000e+02   1.109000e+03
# max    4.245389e+08  5.613827e+06  1.643059e+06   1.228655e+06

# %%
f, ax = plt.subplots(4, 3, figsize = (24, 18))
count = 0
for var in ['views', 'likes', 'dislikes', 'comment_count'] : 
    sns.boxplot(mod_df[var], ax = ax[count, 0])
    sns.distplot(mod_df[var], ax = ax[count, 1])
    sns.violinplot(mod_df[var], ax = ax[count, 2])
    count = count + 1

# %% [markdown]
# Let's take a closer look by excluding some outliers.
# (in the range of 0 to [E(x) + 3 * std(x)] which contains 99.7% of our data).

# %%
f, ax = plt.subplots(4, 3, figsize = (30, 24))
count = 0
for var in ['views', 'likes', 'dislikes', 'comment_count'] :
    upper_boundary = mod_df[var].mean() + 3 * mod_df[var].std() 
    uni = mod_df[mod_df[var] < upper_boundary][var]
    sns.boxplot(uni, ax = ax[count, 0])
    sns.distplot(uni, ax = ax[count, 1])
    sns.violinplot(uni, ax = ax[count, 2])
    count = count + 1

# %% [markdown]
# The the distribution is hugely focused on smaller values since getting a huge number of views, likes, or comments is very rare.

# %% [markdown]
# ### Analysis on published date and time

# %% [markdown]
# Number of trending videos published on each day

# %%
weekdays_list = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun']
def weekday(date) :
    return weekdays_list[date.weekday()]

publish_weekday = mod_df['publish_date'].apply(lambda x: weekday(x))
publish_weekday_count = pd.DataFrame(data = {}, columns = ['Weekday', 'Count'])

for day in weekdays_list :
    count = publish_weekday[publish_weekday == day].count()
    #print(count)
    temp = pd.DataFrame({'Weekday' : [day], 'Count' : [count]})
    #print(temp)
    publish_weekday_count = publish_weekday_count.append(temp) 
sns.barplot(x = publish_weekday_count['Weekday'], y = publish_weekday_count['Count'])

# %% [markdown]
# If we sort it :

# %%
publish_weekday_count = publish_weekday_count.sort_values('Count')
sns.barplot(x = publish_weekday_count['Weekday'], y = publish_weekday_count['Count'])

# %%
f, axes = plt.subplots(figsize = (24, 18))

def time(x) :
    hour = x.hour
    if (x.minute > 30) :
        hour = hour + 1
    if (hour == 24) :
        hour = 0
    return hour

publish_hour = mod_df['publish_time'].apply(lambda x: time(x))
publish_hour_count = pd.DataFrame(data = {}, columns = ['Hour', 'Count'])

for hour in range(0, 24) :
    count = publish_hour[publish_hour == hour].count()
    temp = pd.DataFrame({'Hour' : [hour], 'Count' : [count]})
    publish_hour_count = publish_hour_count.append(temp)
sns.barplot(x = publish_hour_count['Hour'], y = publish_hour_count['Count'], ax = axes)

# %% [markdown]
# Most of the videos are posted between 14:00 and 19:00, while the posted weekday does not have that big effect, apparently. We can observe a slight monotonic increase from Saturday to Friday sequentially.

# %%
f, axes = plt.subplots(figsize = (40, 18))

def time(x) :
    hour = x.hour
    if (x.minute > 30) :
        hour = hour + 1
    if (hour == 24) :
        hour = 0
    return hour

category_series = mod_df['category']
category_count = pd.DataFrame(data = {}, columns = ['Category', 'Count'])

for var in category_list :
    count = category_series[category_series == var].count()
    temp = pd.DataFrame({'Category' : [var], 'Count' : [count]})
    category_count = category_count.append(temp)
    category_count = category_count.sort_values(by = ['Count'], ascending = False)
sns.barplot(x = category_count['Category'], y = category_count['Count'], ax = axes, orient = "v")

# %% [markdown]
# Distribution of title lengths of the videos:

# %%
f, axes = plt.subplots(figsize = (40, 18))

def time(x) :
    hour = x.hour
    if (x.minute > 30) :
        hour = hour + 1
    if (hour == 24) :
        hour = 0
    return hour

title_length = mod_df['title'].apply(lambda x : len(x))
sns.distplot(title_length, ax = axes)

# %% [markdown]
# The distribution is similar to Normal distribution, except the total lenght of a title is probably capped between 0 and 100 since there is no value outside this range.

# %% [markdown]
# ## Bivariate analysis

# %% [markdown]
# ### Analysis on 'views', 'likes', 'dislikes', and 'comment_count'

# %%
num = mod_df[['views', 'likes', 'dislikes', 'comment_count']]
fig, ax = plt.subplots(figsize=(10,6))
_ = sns.heatmap(num.corr(), annot=True, cmap=sns.cubehelix_palette(as_cmap=True), ax=ax)

# %% [markdown]
# We can observe a high correlation between 'likes' and 'views', as well as between 'likes' and 'comment_count'. If we plot each pair:

# %%
fig, ax = plt.subplots(figsize = (15, 10))
_ = plt.scatter(x=mod_df['views'], y=mod_df['likes'], edgecolors="#000000", linewidths=0.5)
_ = ax.set(xlabel="Views", ylabel="Likes")

# %%
fig, ax = plt.subplots(figsize = (15, 10))
_ = plt.scatter(x=mod_df['comment_count'], y=mod_df['likes'], edgecolors="#000000", linewidths=0.5)
_ = ax.set(xlabel="Comments", ylabel="Likes")

# %% [markdown]
# We will be mainly focusing the text portion as our main problem, so let's
# move on to the text analysis.

# %% [markdown]
# # Text Analysis

# %%
import nltk

from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS

from collections import Counter
from nltk.tokenize import RegexpTokenizer
import re

# %%
def wcloud(data,bgcolor):
    plt.figure(figsize = (20,15))
    cloud = WordCloud(background_color = bgcolor, max_words = 100,  max_font_size = 50)
    cloud.generate(' '.join(data))
    plt.imshow(cloud)
    plt.axis('off')

# %% [markdown]
# ## Analyzing videos according to their descriptions.

# %% [markdown]
# Let's see the polarity of the most frequently mentioned words for each category.

# %%
MAX_N = 1000
category_list = mod_df['category'].unique()

#remove all the stopwords from the text
en_stopwords = list(stopwords.words('english'))
de_stopwords = list(stopwords.words('german'))   
fr_stopwords = list(stopwords.words('french'))   
en_stopwords.extend(de_stopwords)
en_stopwords.extend(fr_stopwords)

polarities = list()

for category in category_list:
    tags_word = mod_df[mod_df['category']==category]['description'].str.lower().str.cat(sep=' ')

# removes punctuation,numbers and returns list of words
    tags_word = re.sub('[^A-Za-z]+', ' ', tags_word)
    word_tokens = word_tokenize(tags_word)
    filtered_sentence = [w for w in word_tokens if not w in en_stopwords]
    without_single_chr = [word for word in filtered_sentence if len(word) > 2]

# Remove numbers
    cleaned_data_title = [word for word in without_single_chr if not word.isdigit()]      
    
# Calculate frequency distribution
    word_dist = nltk.FreqDist(cleaned_data_title)
    hnhk = pd.DataFrame(word_dist.most_common(MAX_N),
                    columns=['Word', 'Frequency'])

    compound = .0
    for word in hnhk['Word'].head(MAX_N):
        compound += SentimentIntensityAnalyzer().polarity_scores(word)['compound']
    polarities.append(compound)
    print(category, compound)
    
category_list_df = pd.DataFrame(category_list)
polarities_df = pd.DataFrame(polarities)
tags_sentiment = pd.concat([category_list_df,polarities_df],axis=1)
tags_sentiment.columns = ['category','polarity']
tags_sentiment=tags_sentiment.sort_values('polarity').reset_index()
plt.figure(figsize=(16,10))
sns.set(style="white",context="talk")
ax = sns.barplot(x=tags_sentiment['polarity'],y=tags_sentiment['category'], data=tags_sentiment,orient='h',palette="RdBu")
plt.xlabel("Categories")
plt.ylabel("polarity")
plt.title("Polarity of Categories in Youtube videos")
# Out:
# Film & Animation 9.318699999999998
# Music 15.398200000000005
# Comedy 15.876299999999997
# Entertainment 16.858400000000003
# People & Blogs 14.225999999999999
# Gaming 14.0539
# Sports 12.232299999999999
# News & Politics 17.091900000000006
# Travel & Events 25.4521
# Autos & Vehicles 6.5537
# Howto & Style 18.4257
# Pets & Animals 24.334600000000005
# Education 12.703300000000004
# Science & Technology 6.770400000000002
# Shows 5.638800000000001
# Nonprofits & Activism 12.312100000000004
# Text(0.5, 1.0, 'Polarity of Categories in Youtube videos')

# %% [markdown]
# From this graph, we hypothesize that people rarely include negative words in their description. Let's see what are the most frequently mentioned words for each category.

# %%
some_category = ["Shows", "Travel & Events", "Gaming"]

for category in some_category :
    tags_word = mod_df[mod_df['category']== category]['description'].str.lower().str.cat(sep=' ')

    tags_word = re.sub('[^A-Za-z]+', ' ', tags_word)
    word_tokens = word_tokenize(tags_word)
    filtered_sentence = [w for w in word_tokens if not w in en_stopwords]
    without_single_chr = [word for word in filtered_sentence if len(word) > 2]
    cleaned_data_title = [word for word in without_single_chr if not word.isdigit()]

    wcloud(cleaned_data_title,'white')

# %% [markdown]
# However, description mostly include links to other social media platforms, and it is not so appropriate to conclude something from the sentiment analysis of descriptions. Instead, let's use 'tags' which should be more specific in terms of expressing the video.

# %% [markdown]
# ## Analyzing videos according to their tags

# %% [markdown]
# Let's see the polarity of the most common tags for each category.

# %%
MAX_N = 1000
category_list = mod_df['category'].unique()

#remove all the stopwords from the text
en_stopwords = list(stopwords.words('english'))
de_stopwords = list(stopwords.words('german'))   
fr_stopwords = list(stopwords.words('french'))   
en_stopwords.extend(de_stopwords)
en_stopwords.extend(fr_stopwords)

polarities = list()

for category in category_list:
    tags_word = mod_df[mod_df['category']==category]['tags'].str.lower().str.cat(sep=' ')

# removes punctuation,numbers and returns list of words
    tags_word = re.sub('[^A-Za-z]+', ' ', tags_word)
    word_tokens = word_tokenize(tags_word)
    filtered_sentence = [w for w in word_tokens if not w in en_stopwords]
    without_single_chr = [word for word in filtered_sentence if len(word) > 2]

# Remove numbers
    cleaned_data_title = [word for word in without_single_chr if not word.isdigit()]      
    
# Calculate frequency distribution
    word_dist = nltk.FreqDist(cleaned_data_title)
    hnhk = pd.DataFrame(word_dist.most_common(MAX_N),
                    columns=['Word', 'Frequency'])

    compound = .0
    for word in hnhk['Word'].head(MAX_N):
        compound += SentimentIntensityAnalyzer().polarity_scores(word)['compound']

    polarities.append(compound)
    print(category, compound)
    
category_list_df = pd.DataFrame(category_list)
polarities_df = pd.DataFrame(polarities)
tags_sentiment = pd.concat([category_list_df,polarities_df],axis=1)
tags_sentiment.columns = ['category','polarity']
tags_sentiment=tags_sentiment.sort_values('polarity').reset_index()
plt.figure(figsize=(16,10))
sns.set(style="white",context="talk")
ax = sns.barplot(x=tags_sentiment['polarity'],y=tags_sentiment['category'], data=tags_sentiment,orient='h',palette="RdBu")
plt.xlabel("Categories")
plt.ylabel("polarity")
plt.title("Polarity of Categories in Youtube videos")
# Out:
# Film & Animation 4.512499999999999
# Music 12.581900000000006
# Comedy 10.5827
# Entertainment 8.788199999999998
# People & Blogs 15.509199999999998
# Gaming 8.755399999999998
# Sports 8.067099999999996
# News & Politics -2.5281000000000002
# Travel & Events 10.766600000000004
# Autos & Vehicles 0.011500000000000177
# Howto & Style 13.886699999999996
# Pets & Animals 8.565200000000003
# Education 2.4426999999999994
# Science & Technology 4.513100000000001
# Shows 1.4372000000000007
# Nonprofits & Activism -1.3507999999999996
# Text(0.5, 1.0, 'Polarity of Categories in Youtube videos')

# %% [markdown]
# Surprisingly, 'News & Politics' has the most negative tags, while 'People & Blogs' has the most positive tags. Another interesting category is 'Autos & Vehicles' as its polarity is almost 0.
#
# Let's see what are the most repeated tags in these 3 categories.

# %%
category = 'News & Politics'

tags_word = mod_df[mod_df['category']== category]['tags'].str.lower().str.cat(sep=' ')

tags_word = re.sub('[^A-Za-z]+', ' ', tags_word)
word_tokens = word_tokenize(tags_word)
filtered_sentence = [w for w in word_tokens if not w in en_stopwords]
without_single_chr = [word for word in filtered_sentence if len(word) > 2]
cleaned_data_title = [word for word in without_single_chr if not word.isdigit()]

print('The most common words for ', category)
wcloud(cleaned_data_title,'white')
# Out:
# The most common words for  News & Politics

# %%
category = 'Autos & Vehicles'

tags_word = mod_df[mod_df['category']== category]['tags'].str.lower().str.cat(sep=' ')

tags_word = re.sub('[^A-Za-z]+', ' ', tags_word)
word_tokens = word_tokenize(tags_word)
filtered_sentence = [w for w in word_tokens if not w in en_stopwords]
without_single_chr = [word for word in filtered_sentence if len(word) > 2]
cleaned_data_title = [word for word in without_single_chr if not word.isdigit()]

print('The most common words for ', category)
wcloud(cleaned_data_title,'white')
# Out:
# The most common words for  Autos & Vehicles

# %%
category = 'People & Blogs'

tags_word = mod_df[mod_df['category']== category]['tags'].str.lower().str.cat(sep=' ')

tags_word = re.sub('[^A-Za-z]+', ' ', tags_word)
word_tokens = word_tokenize(tags_word)
filtered_sentence = [w for w in word_tokens if not w in en_stopwords]
without_single_chr = [word for word in filtered_sentence if len(word) > 2]
cleaned_data_title = [word for word in without_single_chr if not word.isdigit()]

print('The most common words for ', category)
wcloud(cleaned_data_title,'white')
# Out:
# The most common words for  People & Blogs

# %% [markdown]
# As we have predicted, 'tags' is a better factor for analyzing videos.

# %% [markdown]
# ## Content-Based Recommendation Engine

# %% [markdown]
# As we have seen before, 'tags' gives much more information to us compared to 'description'. So we will try to make a recommendation engine with the tags of videos.

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
mod_df["tags"]
# Out:
# video_id
# FyZMnhUtLfE    電視劇|"大陸電視劇"|"猎场"|"职场"|"商战"|"爱情"|"都市"|"胡歌"|"陈龙"...
# 7MxiQ4v0EnE    punjabi songs|"punjabi bhangra"|"punjabi music...
# gifPYwArCVQ        prank|"pranks"|"nelk"|"nelkfilmz"|"nelkfilms"
# fy-CuCzaPp8    Rooster Teeth|"RT"|"animation"|"television"|"f...
# aVTAU_4i9AY    Industrial Fan|"Industrial Fan Destruction"|"T...
# m-nZmgHWoEw    rhett and link|"good mythical more"|"rhett and...
# _A5Z00E5gx8    马克|"迪丽热巴"|"麻辣变形计"|"军旅"|"美女"|"感情"|"都市"|"电视剧"|"热...
# uEu5--lyNCE    Achievement Hunter|"AH"|"video game"|"gaming"|...
# FSdg3UVuBKE    sugar pine 7|"steven suptic"|"autumn"|"sick"|"...
# 6xT1Xc7_X3k    danny duncan|"danny duncan 69"|"kevin"|"danny ...
# t3FYESkzjUI    artificial intelligence|"digital human"|"virtu...
# -Toujzk3ysk    DNC Chairwoman Donna Brazile|"Hacks"|"The Insi...
# ThLVteoxnSE    Toronto Maple Leafs|"Maple Leafs"|"Leafs"|"Bos...
# 0kErOtN3q_w    Duterte News Report|"Philippines News Cast"|"T...
# ebztEUmhEMY    stars passed|"stars passed away"|"stars lost"|...
# f-G8fK1LJVU    LIANGELO BALL|"LIANGELO BALL EXPELLED"|"LIANGE...
# objBBRAurLg    Kourtney Kardashian|"Khloe Kardashian"|"Kardas...
# xfmqmmBTRXw    24 Oras November 13 2017|"24 Oras"|"24 Oras Ne...
# PV8maMvPqhw    the food ranger|"trevor james"|"food ranger"|"...
# amEZKmJQ4Io    Drako|"Watch Me Do It"|"watch me"|"migos"|"dap...
# 3zjhB7NYQyg    Achievement Hunter|"AH"|"video game"|"gaming"|...
# F5mzb086QM8    secrets of dairy|"larson dairy farms"|"publix"...
# TIvI07xLPnA    Canada|"CBC"|"CBC News"|"National"|"News"|"The...
# 5lC4IlTjVxk    failarmy|"fail army"|"fails"|"fail laugh"|"fun...
# RbcGCMtlluQ    Alex Jones Infowars|"Infowars.com"|"News Wars"...
# pXEGYQ3DNug    true events|"sony entertainment channel"|"cons...
# WuzMMgFsJFE    sp:ti:home=BOS|"sp:ti:away=TOR"|"sp:dt=2017-11...
# 1UE5Dq1rvUA                                               [none]
# 2B8RO0GcLDw    ShahidMasood|"DrShahidMasood"|"LiveShow"|"Talk...
# xZxOAqiQiGo    ownagepranks|"ownage pranks"|"comedy"|"improv"...
#                                      ...
# voG07pt-KYI         Entertainer|"Pop"|"RCA Records Label"|"ZAYN"
# vDyYMcjf500    fortnite|"fortnite pc"|"fortnite battle royale...
# 3Q2j5ApzSqs    Christina Aguilera feat. Demi Lovato|"Fall In ...
# GfxNGjfSKRY    James Bay|"Taylor Swift"|"Delicate"|"BBC"|"Rad...
# amtC28yfYCM    The Tonight Show|"Jimmy Fallon"|"Mindy Kaling"...
# 9NC2saE5MbQ    camels|"cactus"|"pets"|"livestock"|"animals"|"...
# XdNOI-q70q4    Matt Stonie|"Megatoad"|"Competitive Eating"|"F...
# QgOXIEhHU1Y    Welcome to the party|"Diplo"|"Lil Pump"|"Frenc...
# SQsPvrev_bQ    tyler the creator|"435"|"nice toenails"|"golf ...
# _1LdMWlNYS4    dinosaurs|"dinos"|"paleo"|"paleontology"|"scis...
# AFbu21AGSho    nat geo wild|"national geographic"|"wild"|"wil...
# hHaUQh6Gx-Q    Mustard|"Nick"|"Jonas"|"Anywhere"|"10"|"Summer...
# wI89nVn6LHk    ABC|"americanidol"|"idol"|"american idol"|"rya...
# oLDbO545aKQ    terrible magicians|"rudy"|"mancuso"|"juanpa"|"...
# tiF9SzzzX_o    the voice season 14|"the voice finale performa...
# Gs26bZTRkdU    SciShow|"science"|"Hank"|"Green"|"education"|"...
# Qcj15vHJTtk    SNL|"Saturday Night Live"|"SNL Season 43"|"SNL...
# 2in8XqiElwc    Nicki Minaj new music|"Nicki Minaj Queen"|"Nic...
# Xr2rgT9uEnA    miniminter|"mm7games"|"simon"|"random"|"lie de...
# v7H_Or9Nr5I     LucastheSpider|"Animation"|"3D Animation"|"Cute"
# n_W54baizX8    daddy yankee reggaeton|"daddy yankee youtube"|...
# pcJo0tIWybY    Garden (Say It Like Dat)|"R&B"|"SZA"|"Top Dawg...
# _QWZvU7VCn8    Graham Norton|"Graham Norton Show Official"|"E...
# 7UoP9ABJXGE    wedding video|"heartfelt wedding video"|"emoti...
# ju_inUnrLc4    fifth hamony|"harmonizers"|"lauren"|"ally"|"no...
# 1PhPYr_9zRY    BuzzFeed|"BuzzFeedVideo"|"Puppy Interview"|"pu...
# BZt0qjTWNhw    aarons animals|"aarons"|"animals"|"cat"|"cats"...
# D6Oy4LfoqsU    I gave safiya nygaard a perfect hair makeover ...
# oV0zkMe1K8s    Black Panther|"HISHE"|"Marvel"|"Infinity War"|...
# ooyjaVdt-jA        call of duty|"cod"|"activision"|"Black Ops 4"
# Name: tags, Length: 74947, dtype: object

# %% [markdown]
# Extracting and cleaning the 'tags' column of our dataset

# %%
def clean_text(x) :
    text = x.lower()
    
    text = re.sub('[^A-Za-z]+', ' ', text)
    word_tokens = word_tokenize(text)
    filtered_sentence = [w for w in word_tokens if not w in en_stopwords]
    without_single_chr = [word for word in filtered_sentence if len(word) > 2]
    cleaned_data_title = [word for word in without_single_chr if not word.isdigit()]
    
    return ' '.join(cleaned_data_title)
    
cleaned_tags = mod_df['tags'].apply(lambda x: clean_text(x))

# %% [markdown]
# Vectorize tag strings using CountVectorizer from sklearn, and find similar videos using cosine_similarity between tags

# %%
count_vector = CountVectorizer()
count_vector_matrix = count_vector.fit_transform(cleaned_tags)
indices = pd.Series(cleaned_tags.index)

def recommend_by_id(id) :
    
    recommended_list = []
    
    idx = indices[indices == id].index[0]
    
    cosine_sim = cosine_similarity(count_vector_matrix[idx], count_vector_matrix)
    score_series = pd.Series(cosine_sim[0]).sort_values(ascending = False)
    
    top_10_indexes = list(score_series.iloc[1:11].index)
    print(top_10_indexes)
    for i in top_10_indexes:
        recommended_list.append(list(cleaned_tags.index)[i])

    #create a dataframe of title and thumbnail_link pairs for recommended videos
    recommendation_df = pd.DataFrame({'Title' : [], 'Thumbnail_link' : []})

    for id in recommended_list :
        title = mod_df['title'][id]
        link = mod_df['thumbnail_link'][id]

        df = pd.DataFrame({'Title' : [title], 'Thumbnail_link' : [link]})
        recommendation_df = recommendation_df.append(df)
        
    print("Recommended videos for: ", mod_df['title'][id])
    print(recommendation_df['Title'])
    
    return recommendation_df

# %% [markdown]
# Displaying thumbnails of recommended videos

# %%
from IPython.display import HTML, display

# %%
def display_thumbnail(df) :
    ROW = 5
    COLUMN = 2
    tempHTML = ''
    innerHTML = '<div style="block">'
    
    link_df = df['Thumbnail_link'].reset_index()['Thumbnail_link']
    for r in range(ROW):
        rowHTML = ''
        for c in range(COLUMN):
            tempHTML = '<img src="' + link_df[c*3+r] + '"style="float:left;width:200px;height:200px;margin:0">'
            rowHTML += tempHTML
        innerHTML += rowHTML
    innerHTML += '</div>'
    display(HTML(innerHTML))

# %%
display_thumbnail(recommend_by_id('n1WpP7iowLc'))
# Out:
# [70720, 67208, 39280, 69194, 67997, 6480, 68328, 70098, 44057, 43639]
# Recommended videos for:  Eminem - River (Audio) ft. Ed Sheeran
# 0    Eminem - Walk On Water (Official Video) ft. Be...
# 0                Walk On Water (Official Video Teaser)
# 0    Eminem Performs 'Walk On Water' | MTV EMAs 201...
# 0                Eminem speaks on working with Beyonce
# 0    Eminem - River (Behind the Scenes) ft. Ed Sheeran
# 0                     Rich The Kid - Plug Walk (Audio)
# 0                                      Eminem - Framed
# 0                         Eminem - Untouchable (Audio)
# 0                        Eminem - River ft. Ed Sheeran
# 0                Eminem - River (Audio) ft. Ed Sheeran
# Name: Title, dtype: object
# <div style="block"><img src="https://i.ytimg.com/vi/ryr75N0nki0/default.jpg"style="float:left;width:200px;height:200px;margin:0"><img src="https://i.ytimg.com/vi/By6Mi7VlqcU/default.jpg"style="float:left;width:200px;height:200px;margin:0"><img src="https://i.ytimg.com/vi/4OiHwMtKwis/default.jpg"style="float:left;width:200px;height:200px;margin:0"><img src="https://i.ytimg.com/vi/fTK0hhBiCgA/default.jpg"style="float:left;width:200px;height:200px;margin:0"><img src="https://i.ytimg.com/vi/jEtTDPkjoFc/default.jpg"style="float:left;width:200px;height:200px;margin:0"><img src="https://i.ytimg.com/vi/SXMhL_UoVWw/default.jpg"style="float:left;width:200px;height:200px;margin:0"><img src="https://i.ytimg.com/vi/By6Mi7VlqcU/default.jpg"style="float:left;width:200px;height:200px;margin:0"><img src="https://i.ytimg.com/vi/PVbQrvlB_gw/default.jpg"style="float:left;width:200px;height:200px;margin:0"><img src="https://i.ytimg.com/vi/fTK0hhBiCgA/default.jpg"style="float:left;width:200px;height:200px;margin:0"><img src="https://i.ytimg.com/vi/56KYMMGudcU/default.jpg"style="float:left;width:200px;height:200px;margin:0"></div>

# %% [markdown]
# We successfully obtained our recommendation. However, until this point, we did not really train any specific machine learning model and use it for our recommendation. So, as an extra problem, let's try Gaussian Naive Bayes model to predict the category of a video from its tags.

# %% [markdown]
# # Extra Problem: Category prediction using 'tags'

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %% [markdown]
# Let's cut down our dataset to only trending videos in US because the whole dataset is too big for our devices.

# %%
us_data = mod_df[mod_df["country"] == "US"]
print(us_data.shape)
us_data.head(3)
# Out:
# (6254, 18)
#             trending_date                                              title  \
# video_id
# 9wRQljFNDW8    2017-11-14  Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...
# Om_zGhJLZ5U    2017-11-14     TL;DW - Every DCEU Movie Before Justice League
# goP4Z5wyOlM    2017-11-14  Iraq-Iran earthquake: Deadly tremor hits borde...
#
#               channel_title category_id          category publish_date  \
# video_id
# 9wRQljFNDW8             NFL          17            Sports   2017-11-13
# Om_zGhJLZ5U  Screen Junkies           1  Film & Animation   2017-11-12
# goP4Z5wyOlM        BBC News          25   News & Politics   2017-11-12
#
#             publish_time                                               tags  \
# video_id
# 9wRQljFNDW8     02:05:26  NFL|"Football"|"offense"|"defense"|"afc"|"nfc"...
# Om_zGhJLZ5U     18:00:03  screenjunkies|"screen junkies"|"sj news"|"hone...
# goP4Z5wyOlM     21:16:40  bbc|"bbc news"|"news"|"iran"|"iran news"|"iraq...
#
#               views  likes  dislikes  comment_count  \
# video_id
# 9wRQljFNDW8   81377    655        25            177
# Om_zGhJLZ5U  288922   7515       792           2111
# goP4Z5wyOlM   34785    308        26            413
#
#                                              thumbnail_link  \
# video_id
# 9wRQljFNDW8  https://i.ytimg.com/vi/9wRQljFNDW8/default.jpg
# Om_zGhJLZ5U  https://i.ytimg.com/vi/Om_zGhJLZ5U/default.jpg
# goP4Z5wyOlM  https://i.ytimg.com/vi/goP4Z5wyOlM/default.jpg
#
#              comments_disabled  ratings_disabled  video_error_or_removed  \
# video_id
# 9wRQljFNDW8              False             False                   False
# Om_zGhJLZ5U              False             False                   False
# goP4Z5wyOlM              False             False                   False
#
#                                                    description country
# video_id
# 9wRQljFNDW8  New England Patriots returner Dion Lewis blast...      US
# Om_zGhJLZ5U  With Justice League approaching fast we rewatc...      US
# goP4Z5wyOlM  A strong 7.2-magnitude earthquake has rattled ...      US

# %% [markdown]
# We can not use raw "tags" as the predictor because the "tag" array would not have the uniform length. So we are vectorizing it and using results as our predictor

# %%
us_cleaned_tags = us_data['tags'].apply(lambda x: clean_text(x))
us_count_vector = CountVectorizer()
us_count_vector_matrix = us_count_vector.fit_transform(us_cleaned_tags)

predictor = us_count_vector_matrix.toarray()
target = us_data["category"].to_numpy()

x_train, x_test, y_train, y_test = train_test_split(predictor, target, test_size = 0.20)

model_gnb = GaussianNB()
model_gnb.fit(x_train, y_train)

print("Score on train dataset: ", model_gnb.score(x_train, y_train))
print("Score on test dataset:", model_gnb.score(x_test, y_test))
print("Score on whole dataset:", model_gnb.score(predictor, target))
# Out:
# Score on train dataset:  0.9448331001399161
# Score on test dataset: 0.5899280575539568
# Score on whole dataset: 0.8738407419251679

# %% [markdown]
# The accuracy is not too bad on our train dataset, but it is almost 60% on our test dataset. We assume that it is due to the trending video tags are changing continuously, making it harder to make predictions on new inputs.
